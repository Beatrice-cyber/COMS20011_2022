# %% [markdown]
# Q1 using sin(2 pi nx) plot 3 graphs
# see link https://github.com/Beatrice-cyber/COMS20011_2022/blob/main/ProblemSheets/ProblemSheet-MM03.pdf

# %%
import numpy as np
import matplotlib.pyplot as plt
n1 = 0.25
n2 = 1
n3 = 2
x1 = np.linspace(-3,3,30)
y1 = np.sin(2* np.pi *n1* x)
y2 = np.sin(2* np.pi *n2* x)
y3 = np.sin(2* np.pi *n3* x)
plt.xlim([-3, 3])
plt.plot(x1,y1)
plt.plot(x1,y2)
plt.plot(x1,y3)
plt.plot(x1, y1+y2+y3,"black")
